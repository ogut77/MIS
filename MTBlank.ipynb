# %% [markdown]
# <a href="https://colab.research.google.com/github/ogut77/MIS/blob/main/MTBlank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandasql
import pandas as pd
import pandasql as psql
Course=pd.read_excel("https://github.com/ogut77/University/blob/main/Course.xlsx?raw=true")
Faculty=pd.read_excel("https://github.com/ogut77/University/blob/main/Faculty.xlsx?raw=true")
Student=pd.read_excel("https://github.com/ogut77/University/blob/main/Student.xlsx?raw=true")
Enrollment=pd.read_excel("https://github.com/ogut77/University/blob/main/Enrollment.xlsx?raw=true")
Offering=pd.read_excel("https://github.com/ogut77/University/blob/main/Offering.xlsx?raw=true")
Faculty_1=pd.read_excel("https://github.com/ogut77/University/blob/main/Faculty_1.xlsx?raw=true")
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.2.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.0.47)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2025.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->pandasql) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->pandasql) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.17.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26773 sha256=819eb02fdfd6e6043b3a373c8fd2eb17da709b44b6c04bbde80b62755140dc28
#   Stored in directory: /root/.cache/pip/wheels/15/a1/e7/6f92f295b5272ae5c02365e6b8fa19cb93f16a537090a1cf27
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A **primary key** is a column of table which uniquely identifies each tuple (row) in that table. The primary key does not accept the any duplicate and NULL values.
#
#
# A **foreign key** is a column or group of columns in a relational database table that provides a link between data in two tables.
# It is most often the the primary key of another table.

# %%
#Query 1A-List all student info and
txt='''

'''
Q1A =  psql.sqldf(txt)
Q1A
# Out:
#           StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0   123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 1   124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 2   234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 3   345-67-8901        WALLY     KENDALL  SEATTLE       WA  98123-1141
# 4   456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 5   567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 6   678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 7   789-01-2345      ROBERTO     MORALES  SEATTLE       WA  98121-2212
# 8   876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
# 9   890-12-3456         LUKE      BRAZZI  SEATTLE       WA  98116-0021
# 10  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#    StdMajor StdClass  StdGPA
# 0        IS       FR     3.0
# 1       FIN       JR     2.7
# 2      ACCT       JR     3.5
# 3        IS       SR     2.8
# 4       FIN       SR     3.2
# 5        IS       JR     3.6
# 6      ACCT       SO     3.3
# 7       FIN       JR     2.5
# 8        IS       SR     4.0
# 9        IS       SR     2.2
# 10       IS       SO     3.8

# %%
#Query 1B-List Student's all  enrollment grade from offering(Enrollment Table)
txt='''
Select *
From Enrollment
'''
Q1B =  psql.sqldf(txt)
Q1B
# Out:
#     OfferNo        StdNo  EnrGrade
# 0      1234  123-45-6789       3.3
# 1      1234  234-56-7890       3.5
# 2      1234  345-67-8901       3.2
# 3      1234  456-78-9012       3.1
# 4      1234  567-89-0123       3.8
# 5      1234  678-90-1234       3.4
# 6      4321  123-45-6789       3.5
# 7      4321  124-56-7890       3.2
# 8      4321  789-01-2345       3.5
# 9      4321  876-54-3210       3.1
# 10     4321  890-12-3456       3.4
# 11     4321  901-23-4567       3.1
# 12     5555  123-45-6789       3.2
# 13     5555  124-56-7890       2.7
# 14     5678  123-45-6789       3.2
# 15     5678  234-56-7890       2.8
# 16     5678  345-67-8901       3.3
# 17     5678  456-78-9012       3.4
# 18     5678  567-89-0123       2.6
# 19     5679  123-45-6789       2.0
# 20     5679  124-56-7890       3.7
# 21     5679  678-90-1234       3.3
# 22     5679  789-01-2345       3.8
# 23     5679  890-12-3456       2.9
# 24     5679  901-23-4567       3.1
# 25     6666  234-56-7890       3.1
# 26     6666  567-89-0123       3.6
# 27     7777  876-54-3210       3.4
# 28     7777  890-12-3456       3.7
# 29     7777  901-23-4567       3.4
# 30     9876  124-56-7890       3.5
# 31     9876  234-56-7890       3.2
# 32     9876  345-67-8901       3.2
# 33     9876  456-78-9012       3.4
# 34     9876  567-89-0123       2.6
# 35     9876  678-90-1234       3.3
# 36     9876  901-23-4567       4.0

# %%
#Query 1-List all student info and
#their enrollment grade from a course(Just use two tables)
txt='''


'''
Q1 =  psql.sqldf(txt)
Q1
# Out:
#           StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0   123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 1   123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 2   123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 3   123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 4   123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 5   124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 6   124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 7   124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 8   124-56-7890          BOB     NORBERT  BOTHELL       WA  98011-2121
# 9   234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 10  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 11  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 12  234-56-7890        CANDY     KENDALL   TACOMA       WA  99042-3321
# 13  345-67-8901        WALLY     KENDALL  SEATTLE       WA  98123-1141
# 14  345-67-8901        WALLY     KENDALL  SEATTLE       WA  98123-1141
# 15  345-67-8901        WALLY     KENDALL  SEATTLE       WA  98123-1141
# 16  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 17  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 18  456-78-9012          JOE     ESTRADA  SEATTLE       WA  98121-2333
# 19  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 20  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 21  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 22  567-89-0123       MARIAH       DODGE  SEATTLE       WA  98114-0021
# 23  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 24  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 25  678-90-1234         TESS       DODGE  REDMOND       WA  98116-2344
# 26  789-01-2345      ROBERTO     MORALES  SEATTLE       WA  98121-2212
# 27  789-01-2345      ROBERTO     MORALES  SEATTLE       WA  98121-2212
# 28  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
# 29  876-54-3210   CRISTOPHER       COLAN  SEATTLE       WA  98114-1332
# 30  890-12-3456         LUKE      BRAZZI  SEATTLE       WA  98116-0021
# 31  890-12-3456         LUKE      BRAZZI  SEATTLE       WA  98116-0021
# 32  890-12-3456         LUKE      BRAZZI  SEATTLE       WA  98116-0021
# 33  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
# 34  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
# 35  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
# 36  901-23-4567      WILLIAM     PILGRIM  BOTHELL       WA  98113-1885
#
#    StdMajor StdClass  StdGPA  OfferNo        StdNo  EnrGrade
# 0        IS       FR     3.0     1234  123-45-6789       3.3
# 1        IS       FR     3.0     4321  123-45-6789       3.5
# 2        IS       FR     3.0     5555  123-45-6789       3.2
# 3        IS       FR     3.0     5678  123-45-6789       3.2
# 4        IS       FR     3.0     5679  123-45-6789       2.0
# 5       FIN       JR     2.7     4321  124-56-7890       3.2
# 6       FIN       JR     2.7     5555  124-56-7890       2.7
# 7       FIN       JR     2.7     5679  124-56-7890       3.7
# 8       FIN       JR     2.7     9876  124-56-7890       3.5
# 9      ACCT       JR     3.5     1234  234-56-7890       3.5
# 10     ACCT       JR     3.5     5678  234-56-7890       2.8
# 11     ACCT       JR     3.5     6666  234-56-7890       3.1
# 12     ACCT       JR     3.5     9876  234-56-7890       3.2
# 13       IS       SR     2.8     1234  345-67-8901       3.2
# 14       IS       SR     2.8     5678  345-67-8901       3.3
# 15       IS       SR     2.8     9876  345-67-8901       3.2
# 16      FIN       SR     3.2     1234  456-78-9012       3.1
# 17      FIN       SR     3.2     5678  456-78-9012       3.4
# 18      FIN       SR     3.2     9876  456-78-9012       3.4
# 19       IS       JR     3.6     1234  567-89-0123       3.8
# 20       IS       JR     3.6     5678  567-89-0123       2.6
# 21       IS       JR     3.6     6666  567-89-0123       3.6
# 22       IS       JR     3.6     9876  567-89-0123       2.6
# 23     ACCT       SO     3.3     1234  678-90-1234       3.4
# 24     ACCT       SO     3.3     5679  678-90-1234       3.3
# 25     ACCT       SO     3.3     9876  678-90-1234       3.3
# 26      FIN       JR     2.5     4321  789-01-2345       3.5
# 27      FIN       JR     2.5     5679  789-01-2345       3.8
# 28       IS       SR     4.0     4321  876-54-3210       3.1
# 29       IS       SR     4.0     7777  876-54-3210       3.4
# 30       IS       SR     2.2     4321  890-12-3456       3.4
# 31       IS       SR     2.2     5679  890-12-3456       2.9
# 32       IS       SR     2.2     7777  890-12-3456       3.7
# 33       IS       SO     3.8     4321  901-23-4567       3.1
# 34       IS       SO     3.8     5679  901-23-4567       3.1
# 35       IS       SO     3.8     7777  901-23-4567       3.4
# 36       IS       SO     3.8     9876  901-23-4567       4.0

# %%
#Query 2-List available student information along with their enrollment grades and Offerno
# for the student with Student No '123-45-6789'
txt='''

'''
Q2 =  psql.sqldf(txt)
Q2
# Out:
#          StdNo StdFirstName StdLastName  StdCity StdState      StdZip  \
# 0  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 1  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 2  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 3  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
# 4  123-45-6789        HOMER       WELLS  SEATTLE       WA  98121-1111
#
#   StdMajor StdClass  StdGPA  OfferNo        StdNo  EnrGrade
# 0       IS       FR     3.0     1234  123-45-6789       3.3
# 1       IS       FR     3.0     4321  123-45-6789       3.5
# 2       IS       FR     3.0     5555  123-45-6789       3.2
# 3       IS       FR     3.0     5678  123-45-6789       3.2
# 4       IS       FR     3.0     5679  123-45-6789       2.0

# %%
#Query 3-List the StdNo, student name, offering number,enrollment grade
# of students who have a grade ≥ 3.5 in a course offering.
txt='''


'''
Q3 =  psql.sqldf(txt)
Q3
# Out:
#          StdNo StdFirstName StdLastName  OfferNo  EnrGrade
# 0  234-56-7890        CANDY     KENDALL     1234       3.5
# 1  567-89-0123       MARIAH       DODGE     1234       3.8
# 2  123-45-6789        HOMER       WELLS     4321       3.5
# 3  789-01-2345      ROBERTO     MORALES     4321       3.5
# 4  124-56-7890          BOB     NORBERT     5679       3.7
# 5  789-01-2345      ROBERTO     MORALES     5679       3.8
# 6  567-89-0123       MARIAH       DODGE     6666       3.6
# 7  890-12-3456         LUKE      BRAZZI     7777       3.7
# 8  124-56-7890          BOB     NORBERT     9876       3.5
# 9  901-23-4567      WILLIAM     PILGRIM     9876       4.0

# %%
#Query 4-List the course offering information and instructor's
#first and last name of that course offering
txt='''


'''
Q4=  psql.sqldf(txt)
Q4
# Out:
#     OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0      1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 1      3333    IS320  SPRING     2017      BLM214  08:30:00.000000
# 2      4321    IS320    FALL     2016      BLM214  15:30:00.000000
# 3      4444    IS320  WINTER     2017      BLM302  15:30:00.000000
# 4      5555   FIN300  WINTER     2017      BLM207  08:30:00.000000
# 5      5678    IS480  WINTER     2017      BLM302  10:30:00.000000
# 6      5679    IS480  SPRING     2017      BLM412  15:30:00.000000
# 7      6666   FIN450  WINTER     2017      BLM212  10:30:00.000000
# 8      7777   FIN480  SPRING     2017      BLM305  13:30:00.000000
# 9      8888    IS320  SUMMER     2017      BLM405  13:30:00.000000
# 10     9876    IS460  SPRING     2017      BLM307  13:30:00.000000
#
#           FacNo OffDays FacFirstName FacLastName
# 0   098-76-5432      MW      LEONARD       VINCE
# 1   098-76-5432      MW      LEONARD       VINCE
# 2   098-76-5432     TTH      LEONARD       VINCE
# 3   543-21-0987     TTH     VICTORIA    EMMANUEL
# 4   765-43-2109      MW        NICKI       MACON
# 5   987-65-4321      MW        JULIA       MILLS
# 6   876-54-3210     TTH   CRISTOPHER       COLAN
# 7   987-65-4321     TTH        JULIA       MILLS
# 8   765-43-2109      MW        NICKI       MACON
# 9   654-32-1098      MW      LEONARD       FIBON
# 10  654-32-1098     TTH      LEONARD       FIBON

# %%
#Query 5-Same as Query 4 but add Course Description.
#In other words, list the course offering,
#faculty name, surname and course description.
txt='''

'''
Q5 =  psql.sqldf(txt)
Q5
# Out:
#     OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0      1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 1      3333    IS320  SPRING     2017      BLM214  08:30:00.000000
# 2      4321    IS320    FALL     2016      BLM214  15:30:00.000000
# 3      4444    IS320  WINTER     2017      BLM302  15:30:00.000000
# 4      5555   FIN300  WINTER     2017      BLM207  08:30:00.000000
# 5      5678    IS480  WINTER     2017      BLM302  10:30:00.000000
# 6      5679    IS480  SPRING     2017      BLM412  15:30:00.000000
# 7      6666   FIN450  WINTER     2017      BLM212  10:30:00.000000
# 8      7777   FIN480  SPRING     2017      BLM305  13:30:00.000000
# 9      8888    IS320  SUMMER     2017      BLM405  13:30:00.000000
# 10     9876    IS460  SPRING     2017      BLM307  13:30:00.000000
#
#           FacNo OffDays FacFirstName FacLastName  \
# 0   098-76-5432      MW      LEONARD       VINCE
# 1   098-76-5432      MW      LEONARD       VINCE
# 2   098-76-5432     TTH      LEONARD       VINCE
# 3   543-21-0987     TTH     VICTORIA    EMMANUEL
# 4   765-43-2109      MW        NICKI       MACON
# 5   987-65-4321      MW        JULIA       MILLS
# 6   876-54-3210     TTH   CRISTOPHER       COLAN
# 7   987-65-4321     TTH        JULIA       MILLS
# 8   765-43-2109      MW        NICKI       MACON
# 9   654-32-1098      MW      LEONARD       FIBON
# 10  654-32-1098     TTH      LEONARD       FIBON
#
#                                  CrsDesc
# 0   FUNDAMENTALS OF BUSINESS PROGRAMMING
# 1   FUNDAMENTALS OF BUSINESS PROGRAMMING
# 2   FUNDAMENTALS OF BUSINESS PROGRAMMING
# 3   FUNDAMENTALS OF BUSINESS PROGRAMMING
# 4                FUNDAMENTALS OF FINANCE
# 5    FUNDAMENTALS OF DATABASE MANAGEMENT
# 6    FUNDAMENTALS OF DATABASE MANAGEMENT
# 7              PRINCIPLES OF INVESTMENTS
# 8                      CORPORATE FINANCE
# 9   FUNDAMENTALS OF BUSINESS PROGRAMMING
# 10                      SYSTEMS ANALYSIS

# %%
#Query 6-Same as Query 1 but add Course Description to the table
#In other words,List all student info,Offerno , CourseNo,
#their enrollment grade from a course and course description.
txt='''


'''
Q6 =  psql.sqldf(txt)
Q6

# %%
#Query 7-Same as Query 6 and add Faculty First Name and Faculty Last Name to the table
#
txt='''


'''
Q7 =  psql.sqldf(txt)
Q7

# %%
#Query 8-List LEONARD VINCE’s teaching schedule
# in FALL 2016. For each course,
#list the offering number, course number,Term,Year, location,time and days.
txt='''

'''
Q8 =  psql.sqldf(txt)
Q8
# Out:
#    OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0     1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 1     4321    IS320    FALL     2016      BLM214  15:30:00.000000
#
#          FacNo OffDays FacFirstName FacLastName
# 0  098-76-5432      MW      LEONARD       VINCE
# 1  098-76-5432     TTH      LEONARD       VINCE

# %%
#Query 9-In addition to Query 8, add Course Description to the Table.
txt='''

'''
Q9 =  psql.sqldf(txt)
Q9
# Out:
#    OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0     1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 1     4321    IS320    FALL     2016      BLM214  15:30:00.000000
#
#          FacNo OffDays FacFirstName FacLastName  \
# 0  098-76-5432      MW      LEONARD       VINCE
# 1  098-76-5432     TTH      LEONARD       VINCE
#
#                                 CrsDesc
# 0  FUNDAMENTALS OF BUSINESS PROGRAMMING
# 1  FUNDAMENTALS OF BUSINESS PROGRAMMING

# %%
#Query 10-List Student BOB NORBERT’s course schedule in
#SPRING 2017. For each course, list the offering number,
# course number, days, location, time and instructor's name.
txt='''

'''
Q10 =  psql.sqldf(txt)
Q10
# Out:
#    OfferNo CourseNo OffDays OffLocation          OffTime FacFirstName  \
# 0     5679    IS480     TTH      BLM412  15:30:00.000000   CRISTOPHER
# 1     9876    IS460     TTH      BLM307  13:30:00.000000      LEONARD
#
#   FacLastName
# 0       COLAN
# 1       FIBON

# %%
#Query 11-List the course number,the offering number,
# the number of students enrolled and offering's average enrollment grade.

txt='''

'''
Q11 =  psql.sqldf(txt)
Q11
# Out:
#    OfferNo CourseNo  Count(StdNo)  Avg(EnrGrade)
# 0     1234    IS320             6       3.383333
# 1     4321    IS320             6       3.300000
# 2     5555   FIN300             2       2.950000
# 3     5678    IS480             5       3.060000
# 4     5679    IS480             6       3.133333
# 5     6666   FIN450             2       3.350000
# 6     7777   FIN480             3       3.500000
# 7     9876    IS460             7       3.314286

# %%
#Query 12-List the course number, offer number,
# and average enrollment grade for course offerings  in which
#the average enrollment grade is greater than 3.2
txt='''


'''
Q12 =  psql.sqldf(txt)
Q12
# Out:
#    OfferNo CourseNo  Count(StdNo)  Avg(EnrGrade)
# 0     1234    IS320             6       3.383333
# 1     4321    IS320             6       3.300000
# 2     6666   FIN450             2       3.350000
# 3     7777   FIN480             3       3.500000
# 4     9876    IS460             7       3.314286

# %%
#Query 13-How many courses are offered by each faculty?
#Add Faculty FirstName and Last Name to the query result.
txt='''

'''
Q13 =  psql.sqldf(txt)
Q13
# Out:
#          FacNo FacFirstName FacLastName  Count(*)
# 0  098-76-5432      LEONARD       VINCE         3
# 1  543-21-0987     VICTORIA    EMMANUEL         1
# 2  654-32-1098      LEONARD       FIBON         2
# 3  765-43-2109        NICKI       MACON         2
# 4  876-54-3210   CRISTOPHER       COLAN         1
# 5  987-65-4321        JULIA       MILLS         2

# %%
#Query 14-How many different courses are offered by each faculty?
#Add Faculty FirstName and Last Name to the query result.
txt='''


'''
Q14 =  psql.sqldf(txt)
Q14
# Out:
#          FacNo FacFirstName FacLastName  Count(Distinct CourseNo)
# 0  098-76-5432      LEONARD       VINCE                         1
# 1  543-21-0987     VICTORIA    EMMANUEL                         1
# 2  654-32-1098      LEONARD       FIBON                         2
# 3  765-43-2109        NICKI       MACON                         2
# 4  876-54-3210   CRISTOPHER       COLAN                         1
# 5  987-65-4321        JULIA       MILLS                         2

# %% [markdown]
# # **REVIEW**

# %%
#List number of offering per year
txt='''

'''
QR1 =  psql.sqldf(txt)
QR1
# Out:
#    OffYear  NoOfOffering
# 0     2016             3
# 1     2017            10

# %%
#List number of offering per semester and year
txt='''

'''
QR2 =  psql.sqldf(txt)
QR2
# Out:
#    OffYear OffTerm  NoOfOffering
# 0     2016    FALL             2
# 1     2016  SUMMER             1
# 2     2017  SPRING             4
# 3     2017  SUMMER             2
# 4     2017  WINTER             4

# %%
#List number of offering and average enrollment grade per semester

txt='''


'''
QR3 =  psql.sqldf(txt)
QR3
# Out:
#    OffYear OffTerm  NoOfOffering  AvgEnrGrade
# 0     2016    FALL             2     3.341667
# 1     2017  SPRING             3     3.281250
# 2     2017  WINTER             3     3.100000

# %% [markdown]
# SUBQUERY

# %%
#Query 24I-Find StdNo,StdFirstName,StdLastName of Student with
#StdGPA greater than student with StdNo '123-45-6789'
#I-Find the GPA of student having StdNo  '123-45-6789'
#II-Find StdNo,StdFirstName,StdLastName of Student'StdGPA greater than GPA found in part I.
#Combine I and II
txt='''


'''
Q24I =  psql.sqldf(txt)
Q24I
# Out:
#    StdGPA
# 0     3.0

# %%
#II-Find StdNo,StdFirstName,StdLastName and Student GPA of Student
#with StdGPA greater than 3.0
txt='''

'''
Q24II =  psql.sqldf(txt)
Q24II
# Out:
#          StdNo StdFirstName StdLastName  StdGPA
# 0  234-56-7890        CANDY     KENDALL     3.5
# 1  456-78-9012          JOE     ESTRADA     3.2
# 2  567-89-0123       MARIAH       DODGE     3.6
# 3  678-90-1234         TESS       DODGE     3.3
# 4  876-54-3210   CRISTOPHER       COLAN     4.0
# 5  901-23-4567      WILLIAM     PILGRIM     3.8

# %%
#Step 2 is not enough as StdGPA of student can change over time
#So we have to make it more general. In order to do that we will
#Combine II and I
txt='''

'''
Q24 =  psql.sqldf(txt)
Q24

# %%
#Query25-List Faculty Name and Lastname with a Salary higher than 'NICKI MACON'
#I-Write query for Salary of 'NICKI MACON'
#II-Write QUery for FacLastName and FirstName with a Higher salary than salary found in part I
#Combine I and II
txt='''

'''
Q25I =  psql.sqldf(txt)
Q25I
# Out:
#    FacSalary
# 0      65000

# %%
#II-LIst Faculty information who have higher salary than 65000

txt='''

'''
Q25II =  psql.sqldf(txt)
Q25II
# Out:
#   FacFirstName FacLastName  FacSalary
# 0     VICTORIA    EMMANUEL     120000
# 1      LEONARD       FIBON      70000
# 2        JULIA       MILLS      75000

# %%
#Combine II and I as Salary of 'NICKI MACON' can change
txt='''

'''
Q25 =  psql.sqldf(txt)
Q25
# Out:
#   FacFirstName FacLastName  FacSalary
# 0     VICTORIA    EMMANUEL     120000
# 1      LEONARD       FIBON      70000
# 2        JULIA       MILLS      75000

# %%
#List Name of The Faculty who earned less than average salaray of the faculty
#I-Calculate average salary
#-List name of The Faculty who earned less than average salary calculated in I
txt='''

'''
Q26I =  psql.sqldf(txt)
Q26I
# Out:
#    Avg(FacSalary)
# 0         67500.0

# %%
txt='''


'''
Q26 =  psql.sqldf(txt)
Q26
# Out:
#          FacNo FacFirstName FacLastName   FacCity FacState FacDept FacRank  \
# 0  098-76-5432      LEONARD       VINCE   SEATTLE       WA      MS    ASST
# 1  765-43-2109        NICKI       MACON  BELLEVUE       WA     FIN    PROF
# 2  876-54-3210   CRISTOPHER       COLAN   SEATTLE       WA      MS    ASST
#
#    FacSalary
# 0      35000
# 1      65000
# 2      40000

# %%
# List faculty name and lastname who are NOT teaching WINTER 2017
#I-Find FacNo from offering Table who are Offering Course
#II-Get that name if FacNo is NOT in that list
txt='''

'''
Q27I =  psql.sqldf(txt)
Q27I
# Out:
#          FacNo
# 0  543-21-0987
# 1  765-43-2109
# 2  987-65-4321
# 3  987-65-4321

# %%
txt='''

'''
Q27II =  psql.sqldf(txt)
Q27II

# %%
#Q28-List all courses who are not offered. Use nested queries
#Hint First list course offered .

txt='''

'''
Q28 =  psql.sqldf(txt)
Q28
# Out:
#                         CrsDesc
# 0  BUSINESS DATA COMMUNICATIONS

# %% [markdown]
# ### **JOIN**

# %% [markdown]
# ![sqlJoins_7.png](data:image/png;base64,...)

# %% [markdown]
# #Inner Join: Includes only common rows from table 1 and 2
#
# SELECT column_name(s)
# FROM table1
# INNER JOIN table2
# ON table1.column_name = table2.column_name
#
# #Left Join : Include all rows from table 1 and matching rows from table 2
# SELECT column_name(s)
# FROM table1
# LEFT JOIN table2
# ON table1.column_name = table2.column_name
#
# #Right Join : Include all rows from table 1 and matching rows from table 2
# SELECT column_name(s)
# FROM table1
# RIGHT JOIN table2
# ON table1.column_name = table2.column_name
#
# #Full Outer Join : Include all rows from table 1 and table 2
# SELECT column_name(s)
# FROM table1
# FULL OUTER  JOIN table2
# ON table1.column_name = table2.column_name
#
# #Cross Join:A record in table1 is paired with all record on table 2
# SELECT column_name(s)
# FROM table1,table2
#
# #NOT 1: INNER JOIN is the same as
#
# SELECT column_name(s)
# FROM table1,table2
# WHERE table1.column_name = table2.column_name
#
#
# #NOT 2: Right join and Full Outer Join is not supported in Sql lite
# #For right join, you can use
#
# SELECT column_name(s)
# FROM table2
# LEFT JOIN table1
# ON table1.column_name = table2.column_name

# %%
#Q18-Show Course Offering and Faculty Last Name and First Name.
# If Faculty is not assigned to course offering, show that as well.
txt='''

'''
Q18 =  psql.sqldf(txt)
Q18
# Out:
#     OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0      1111    IS320  SUMMER     2017      BLM302  10:30:00.000000
# 1      1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 2      2222    IS460  SUMMER     2016      BLM412  13:30:00.000000
# 3      3333    IS320  SPRING     2017      BLM214  08:30:00.000000
# 4      4321    IS320    FALL     2016      BLM214  15:30:00.000000
# 5      4444    IS320  WINTER     2017      BLM302  15:30:00.000000
# 6      5555   FIN300  WINTER     2017      BLM207  08:30:00.000000
# 7      5678    IS480  WINTER     2017      BLM302  10:30:00.000000
# 8      5679    IS480  SPRING     2017      BLM412  15:30:00.000000
# 9      6666   FIN450  WINTER     2017      BLM212  10:30:00.000000
# 10     7777   FIN480  SPRING     2017      BLM305  13:30:00.000000
# 11     8888    IS320  SUMMER     2017      BLM405  13:30:00.000000
# 12     9876    IS460  SPRING     2017      BLM307  13:30:00.000000
#
#           FacNo OffDays FacFirstName FacLastName
# 0          None      MW         None        None
# 1   098-76-5432      MW      LEONARD       VINCE
# 2          None     TTH         None        None
# 3   098-76-5432      MW      LEONARD       VINCE
# 4   098-76-5432     TTH      LEONARD       VINCE
# 5   543-21-0987     TTH     VICTORIA    EMMANUEL
# 6   765-43-2109      MW        NICKI       MACON
# 7   987-65-4321      MW        JULIA       MILLS
# 8   876-54-3210     TTH   CRISTOPHER       COLAN
# 9   987-65-4321     TTH        JULIA       MILLS
# 10  765-43-2109      MW        NICKI       MACON
# 11  654-32-1098      MW      LEONARD       FIBON
# 12  654-32-1098     TTH      LEONARD       FIBON

# %%
#Q19-If we use inner join or our regular method' we get the following result. Notice that
#2 less records are reported in the query.
txt='''

'''
Q19 =  psql.sqldf(txt)
Q19
# Out:
#     OfferNo CourseNo OffTerm  OffYear OffLocation          OffTime  \
# 0      1234    IS320    FALL     2016      BLM302  10:30:00.000000
# 1      3333    IS320  SPRING     2017      BLM214  08:30:00.000000
# 2      4321    IS320    FALL     2016      BLM214  15:30:00.000000
# 3      4444    IS320  WINTER     2017      BLM302  15:30:00.000000
# 4      5555   FIN300  WINTER     2017      BLM207  08:30:00.000000
# 5      5678    IS480  WINTER     2017      BLM302  10:30:00.000000
# 6      5679    IS480  SPRING     2017      BLM412  15:30:00.000000
# 7      6666   FIN450  WINTER     2017      BLM212  10:30:00.000000
# 8      7777   FIN480  SPRING     2017      BLM305  13:30:00.000000
# 9      8888    IS320  SUMMER     2017      BLM405  13:30:00.000000
# 10     9876    IS460  SPRING     2017      BLM307  13:30:00.000000
#
#           FacNo OffDays FacFirstName FacLastName
# 0   098-76-5432      MW      LEONARD       VINCE
# 1   098-76-5432      MW      LEONARD       VINCE
# 2   098-76-5432     TTH      LEONARD       VINCE
# 3   543-21-0987     TTH     VICTORIA    EMMANUEL
# 4   765-43-2109      MW        NICKI       MACON
# 5   987-65-4321      MW        JULIA       MILLS
# 6   876-54-3210     TTH   CRISTOPHER       COLAN
# 7   987-65-4321     TTH        JULIA       MILLS
# 8   765-43-2109      MW        NICKI       MACON
# 9   654-32-1098      MW      LEONARD       FIBON
# 10  654-32-1098     TTH      LEONARD       FIBON
